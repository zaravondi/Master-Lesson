# %%
import pandas as pd
import requests

# %% [markdown]
# ### Call API at 1.50pm, of 19 Dec 2018

# %%
result = requests.get("https://api.data.gov.sg/v1/transport/traffic-images")

# %%
type(result)
# Out:
# requests.models.Response

# %%
output = result.json()
output
# Out:
# {'items': [{'timestamp': '2018-12-19T12:49:12+08:00',
#    'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#      'location': {'latitude': 1.29531332, 'longitude': 103.871146},
#      'camera_id': '1001',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': '495591fb44aff1a1b56c6dd1f3538669'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#      'location': {'latitude': 1.319541067, 'longitude': 103.8785627},
#      'camera_id': '1002',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
# ...

# %%
output.keys()
# Out:
# dict_keys(['items', 'api_info'])

# %%
output['items']
# Out:
# [{'timestamp': '2018-12-19T12:49:12+08:00',
#   'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00',
#     'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#     'location': {'latitude': 1.29531332, 'longitude': 103.871146},
#     'camera_id': '1001',
#     'image_metadata': {'height': 240,
#      'width': 320,
#      'md5': '495591fb44aff1a1b56c6dd1f3538669'}},
#    {'timestamp': '2018-12-19T12:47:12+08:00',
#     'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#     'location': {'latitude': 1.319541067, 'longitude': 103.8785627},
#     'camera_id': '1002',
#     'image_metadata': {'height': 240,
#      'width': 320,
#      'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}},
#    {'timestamp': '2018-12-19T12:47:12+08:00',
#     'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
# ...

# %%
output_items = output['items']

# %%
type(output_items)
# Out:
# list

# %%
output_item = {}
for i in output_items:
    print(i)
    print(type(i))
    output_item.update(i)
# Out:
# {'timestamp': '2018-12-19T12:49:12+08:00', 'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg', 'location': {'latitude': 1.29531332, 'longitude': 103.871146}, 'camera_id': '1001', 'image_metadata': {'height': 240, 'width': 320, 'md5': '495591fb44aff1a1b56c6dd1f3538669'}}, {'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg', 'location': {'latitude': 1.319541067, 'longitude': 103.8785627}, 'camera_id': '1002', 'image_metadata': {'height': 240, 'width': 320, 'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}}, {'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg', 'location': {'latitude': 1.323957439, 'longitude': 103.8728576}, 'camera_id': '1003', 'image_metadata': {'height': 240, 'width': 320, 'md
# ...

# %%
output_item
# Out:
# {'timestamp': '2018-12-19T12:49:12+08:00',
#  'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00',
#    'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#    'location': {'latitude': 1.29531332, 'longitude': 103.871146},
#    'camera_id': '1001',
#    'image_metadata': {'height': 240,
#     'width': 320,
#     'md5': '495591fb44aff1a1b56c6dd1f3538669'}},
#   {'timestamp': '2018-12-19T12:47:12+08:00',
#    'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#    'location': {'latitude': 1.319541067, 'longitude': 103.8785627},
#    'camera_id': '1002',
#    'image_metadata': {'height': 240,
#     'width': 320,
#     'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}},
#   {'timestamp': '2018-12-19T12:47:12+08:00',
#    'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
# ...

# %%
print(len(output_item))
# Out:
# 2

# %%
output_item["cameras"]
# Out:
# [{'timestamp': '2018-12-19T12:47:12+08:00',
#   'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#   'location': {'latitude': 1.29531332, 'longitude': 103.871146},
#   'camera_id': '1001',
#   'image_metadata': {'height': 240,
#    'width': 320,
#    'md5': '495591fb44aff1a1b56c6dd1f3538669'}},
#  {'timestamp': '2018-12-19T12:47:12+08:00',
#   'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#   'location': {'latitude': 1.319541067, 'longitude': 103.8785627},
#   'camera_id': '1002',
#   'image_metadata': {'height': 240,
#    'width': 320,
#    'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}},
#  {'timestamp': '2018-12-19T12:47:12+08:00',
#   'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
#   'location': {'latitude': 1.323957439, 'longitude': 103.8728576},
#   'camera_id': '1003',
# ...

# %%
type(output_item["timestamp"])
# Out:
# str

# %%
len(output_item["cameras"])
# Out:
# 58

# %%
type(output_item["cameras"])
# Out:
# list

# %%
for i in output_item["cameras"]:
    print(i)
    print(type(i))
# Out:
# {'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg', 'location': {'latitude': 1.29531332, 'longitude': 103.871146}, 'camera_id': '1001', 'image_metadata': {'height': 240, 'width': 320, 'md5': '495591fb44aff1a1b56c6dd1f3538669'}}
# <class 'dict'>
# {'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg', 'location': {'latitude': 1.319541067, 'longitude': 103.8785627}, 'camera_id': '1002', 'image_metadata': {'height': 240, 'width': 320, 'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}}
# <class 'dict'>
# ...

# %%
#an item from output_item["camera"]
{'timestamp': '2018-12-18T13:51:27+08:00', 
 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b1adeb02-01a6-4d08-a4fc-ef43e124e025.jpg', 
 'location': 
     {'latitude': 1.34355015, 'longitude': 103.8601984}, 
 'camera_id': '1702', 
 'image_metadata': {'height': 480, 'width': 640, 'md5': 'eaf1005da951af08b797e7a7a4f5fa3c'}
}
# Out:
# {'timestamp': '2018-12-18T13:51:27+08:00',
#  'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b1adeb02-01a6-4d08-a4fc-ef43e124e025.jpg',
#  'location': {'latitude': 1.34355015, 'longitude': 103.8601984},
#  'camera_id': '1702',
#  'image_metadata': {'height': 480,
#   'width': 640,
#   'md5': 'eaf1005da951af08b797e7a7a4f5fa3c'}}

# %%
{"items":
 [
     {"timestamp":"2018-12-18T13:49:47+08:00",
      "cameras":[
          {"timestamp":"2018-12-18T13:49:27+08:00",
           "image":"https://images.data.gov.sg/api/traffic-images/2018/12/b23db70c-30db-47b4-a6c4-f76ad4afb610.jpg",
           "location":{"latitude":1.31384231654635,"longitude":103.845603032574},
           "camera_id":"1709",
           "image_metadata":
               {"height":480,"width":640,"md5":"946aa1242a19359780bfeb8f790ef97e"}
          },
          {"timestamp":"2018-12-18T13:49:27+08:00",
           "image":"https://images.data.gov.sg/api/traffic-images/2018/12/441b7e8f-209f-4cd7-9426-baebb4b1b0d2.jpg",
           "location":{"latitude":1.447023728,"longitude":103.7716543},
           "camera_id":"2701",
           "image_metadata":
               {"height":480,"width":640,"md5":"eedc00714a59726ad5d13f5f671b3ef7"
               }
          },
          {"timestamp":"2018-12-18T13:49:27+08:00","image":"https://images.data.gov.sg/api/traffic-images/2018/12/bee5382d-b942-402c-8177-47e826c905b8.jpg","location":{"latitude":1.445554109,"longitude":103.7683397},"camera_id":"2702","image_metadata":{"height":480,"width":640,"md5":"592895ad81ff6f4c16dab0f1ec874768"}},{"timestamp":"2018-12-18T13:49:27+08:00","image":"https://images.data.gov.sg/api/traffic-images/2018/12/f3207551-dde4-468b-9b52-e1ce933ce48f.jpg","location":{"latitude":1.348697862,"longitude":103.6350413},"camera_id":"4703","image_metadata":{"height":480,"width":640,"md5":"9a441846425e9185d33a08be08cff0ab"}},{"timestamp":"2018-12-18T13:49:27+08:00","image":"https://images.data.gov.sg/api/traffic-images/2018/12/5b57475c-017a-4dda-9faf-ab8fd3a0d373.jpg","location":{"latitude":1.32153,"longitude":103.75273},"camera_id":"4710","image_metadata":{"height":480,"width":640,"md5":"6b5c0f5d96dd02c060d16f0173b262e9"}},{"timestamp":"2018-12-18T13:49:27+08:00","image":"https://images.data.gov.sg/api/traffic-images/2018/12/ac0c5a70-8262-4e7c-86d9-1243835de001.jpg","location":{"latitude":1.347645829,"longitude":103.6366955},"camera_id":"4713","image_metadata":{"height":480,"width":640,"md5":"af8f6b7942ef47762bfae1927b9a5d50"}},{"timestamp":"2018-12-18T13:47:27+08:00","image":"https://images.data.gov.sg/api/traffic-images/2018/12/997944c7-973a-4cf7-8ad4-03e36002d6e5.jpg","location":{"latitude":1.29531332,"longitude":103.871146},"camera_id":"1001","image_metadata":{"height":240,"width":320,"md5":"08c9f913d740978b4226c81259361377"}},{"timestamp":"2018-12-18T13:47:27+08:00","image":"https://images.data.gov.sg/api/traffic-images/2018/12/f74ce7c6-ff47-49ff-a2de-22c23ef7af9c.jpg","location":{"latitude":1.319541067,"longitude":103.8785627},"camera_id":"1002","image_metadata":{"height":240,"width":320,"md5":"a928df19b0bcd39a7268d3d5faee9028"}},{"timestamp":"2018-12-18T13:47:27+08:00","image":"https://images.data.gov.sg/api/traffic-images/2018/12
08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b23db70c-30db-47b4-a6c4-f76ad4afb610.jpg',
#      'location': {'latitude': 1.31384231654635, 'longitude': 103.845603032574},
#      'camera_id': '1709',
#      'image_metadata': {'height': 480,
#       'width': 640,
#       'md5': '946aa1242a19359780bfeb8f790ef97e'}},
#     {'timestamp': '2018-12-18T13:49:27+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/441b7e8f-209f-4cd7-9426-baebb4b1b0d2.jpg',
#      'location': {'latitude': 1.447023728, 'longitude': 103.7716543},
#      'camera_id': '2701',
#      'image_metadata': {'height': 480,
#       'width': 640,
#       'md5': 'eedc00714a59726ad5d13f5f671b3ef7'}},
#     {'timestamp': '2018-12-18T13:49:27+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/bee5382d-b942-402c-8177-47e826c905b8.jpg',
# ...

# %%
img_urls = []
camera_id = []
# output_item["cameras"] keys are 1)timestamp, 2)image, 3)location, 4)camera_id, 5)image_metadata

for i in output_item["cameras"]:
    img_urls.append((i["image"]))
    camera_id.append((i["camera_id"]))

len(img_urls)
# Out:
# 58

# %%
camera_id
# Out:
# ['1001',
#  '1002',
#  '1003',
#  '1004',
#  '1005',
#  '1006',
#  '1705',
#  '1707',
#  '1709',
#  '9704',
#  '1501',
#  '1502',
#  '1503',
#  '1504',
#  '1505',
#  '2705',
#  '4706',
#  '4708',
#  '1701',
#  '1702',
#  '1704',
#  '1706',
#  '4710',
#  '3796',
#  '6705',
#  '6710',
#  '6711',
#  '6712',
#  '6713',
#  '7795',
#  '1703',
#  '2703',
#  '2704',
#  '3702',
#  '3795',
#  '3797',
#  '4702',
#  '4704',
#  '4705',
#  '4707',
#  '4709',
#  '4712',
#  '4714',
#  '4716',
#  '4798',
#  '4799',
#  '5794',
#  '5795',
#  '5797',
#  '5798',
#  '5799',
#  '6706',
#  '9706',
#  '6701',
#  '7796',
#  '8701',
#  '8702',
#  '8704']

# %%
camera_id = [int(x) for x in camera_id]

# %%
camera_id
# Out:
# [1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1705,
#  1707,
#  1709,
#  9704,
#  1501,
#  1502,
#  1503,
#  1504,
#  1505,
#  2705,
#  4706,
#  4708,
#  1701,
#  1702,
#  1704,
#  1706,
#  4710,
#  3796,
#  6705,
#  6710,
#  6711,
#  6712,
#  6713,
#  7795,
#  1703,
#  2703,
#  2704,
#  3702,
#  3795,
#  3797,
#  4702,
#  4704,
#  4705,
#  4707,
#  4709,
#  4712,
#  4714,
#  4716,
#  4798,
#  4799,
#  5794,
#  5795,
#  5797,
#  5798,
#  5799,
#  6706,
#  9706,
#  6701,
#  7796,
#  8701,
#  8702,
#  8704]

# %%
camera_id = [1701,
 1702,
 1704,
 1707,
 1709,
 1711,
 2701,
 2702,
 4703,
 4710,
 4713,
 1502,
 1503,
 1504,
 1505,
 1705,
 1706,
 2703,
 2704,
 2705,
 2706,
 2708,
 3702,
 3704,
 3705,
 3793,
 3795,
 3796,
 3798,
 4701,
 4702,
 4704,
 4705,
 4707,
 4708,
 4712,
 4714,
 4716,
 4798,
 4799,
 5794,
 5795,
 5797,
 5798,
 5799,
 6701,
 6703,
 6704,
 6705,
 6706,
 6708,
 6710,
 6711,
 6712,
 6713,
 6714,
 6715,
 6716,
 7791,
 7793,
 7794,
 7795,
 7796,
 7797,
 7798,
 8701,
 8702,
 8704,
 8706,
 9701,
 9702,
 9703,
 9704,
 9705,
 9706,
 1001,
 1002,
 1003,
 1004,
 1005,
 1006,
 1501,
 1703,
 2707,
 3797,
 4706,
 4709]

# %%
camera_id
# Out:
# [1701,
#  1702,
#  1704,
#  1707,
#  1709,
#  1711,
#  2701,
#  2702,
#  4703,
#  4710,
#  4713,
#  1502,
#  1503,
#  1504,
#  1505,
#  1705,
#  1706,
#  2703,
#  2704,
#  2705,
#  2706,
#  2708,
#  3702,
#  3704,
#  3705,
#  3793,
#  3795,
#  3796,
#  3798,
#  4701,
#  4702,
#  4704,
#  4705,
#  4707,
#  4708,
#  4712,
#  4714,
#  4716,
#  4798,
#  4799,
#  5794,
#  5795,
#  5797,
#  5798,
#  5799,
#  6701,
#  6703,
#  6704,
#  6705,
#  6706,
#  6708,
#  6710,
#  6711,
#  6712,
#  6713,
#  6714,
#  6715,
#  6716,
#  7791,
#  7793,
#  7794,
#  7795,
#  7796,
#  7797,
#  7798,
#  8701,
#  8702,
#  8704,
#  8706,
#  9701,
#  9702,
#  9703,
#  9704,
#  9705,
#  9706,
#  1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1501,
#  1703,
#  2707,
#  3797,
#  4706,
#  4709]

# %%
img_urls
# Out:
# ['https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/d9e1426f-0d66-4423-9f8b-033d0eb537ec.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/588830cc-51f8-4fae-ab0f-9891d8ddf322.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/7783bf53-aac7-4e70-b99a-7336f7612b33.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/d88ed310-4dce-4027-802c-3db7d5c18312.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/83e8a2c5-2b8a-4bde-8a3f-bce0f81f44cf.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/2d6c9e9e-c692-4702-a4b1-50e08fc3b99f.jpg',
# ...

# %%
img_urls = ['https://images.data.gov.sg/api/traffic-images/2018/12/7571e444-5f1d-41a5-ab23-81b1bd067070.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/b1adeb02-01a6-4d08-a4fc-ef43e124e025.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/b8a4dd07-c7c4-4abb-8aec-f2bc396807aa.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/165c1094-c6a9-46b9-94f2-f874c6bf5b3b.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/4bff3059-ef0f-46e7-8f17-7855de1c2213.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/c33f2ff3-5af8-4bf3-972f-c12d6f025f4a.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/6d915ca2-1100-4346-a2aa-5ce1e237ef72.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/a6b9ddc7-7873-4975-bb4b-9f0fe33a477b.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/5c4b008d-63d7-41f1-889a-13c7939822ed.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/56c2cd81-1a6d-4a1d-b50b-3109510918c5.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/96cfb009-6906-4a1d-bc04-3542e48af348.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/5abe4e58-6937-4f39-9e04-b9892ca42fbd.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/f8ef176e-e23d-4583-8fc0-2d2bddfed799.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/7f255baf-6c38-4d45-9cf4-9d933ac7b981.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/5878e7d6-1abf-4013-8db2-7b21dc271994.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/c47854e3-220f-45a2-bd7d-d5fff7a3ec18.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/8b4426de-6779-48e5-ad26-27152ed2277d.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/4594c20b-1388-4fbc-8104-ae6c4ae792af.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/c20f6824-4cf0-43f0-b82e-324e6dc464f5.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/b235974b-a75e-4479-8014-ba9f936fe978.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/f21ad05c-620f-42ab-a2a0-62d25b01a355.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/5fece100-957c-4299-ac7f-31a72ba4d0ac.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/a29ce856-b335-4a47-a47f-3ae50e67664a.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/
.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/f74ce7c6-ff47-49ff-a2de-22c23ef7af9c.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/02128665-fae3-4d1d-9cad-68ea84c992a9.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/3320d47e-f5a6-4a28-bb2d-4b753f4351e3.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/1ca256e3-0c3f-4f59-a7cb-8dd5f01297e3.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/b058103f-aa00-48dc-b1f4-e83e8d36150b.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/b3d53974-daba-44bb-9469-3ee7b3311be1.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/d514c15e-0b8c-48e9-9d73-6db99b9605aa.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/772eff7c-a388-4030-8975-d1929e24a2ac.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/8af23f8a-7815-4ded-b96c-cde61e455fae.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/ca6e44c7-d33f-482b-8a72-08ed5c56be1b.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/ce4c0235-4e91-4253-a876-cd37409f1a76.jpg']

# %%
img_urls
# Out:
# ['https://images.data.gov.sg/api/traffic-images/2018/12/7571e444-5f1d-41a5-ab23-81b1bd067070.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/b1adeb02-01a6-4d08-a4fc-ef43e124e025.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/b8a4dd07-c7c4-4abb-8aec-f2bc396807aa.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/165c1094-c6a9-46b9-94f2-f874c6bf5b3b.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/4bff3059-ef0f-46e7-8f17-7855de1c2213.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/c33f2ff3-5af8-4bf3-972f-c12d6f025f4a.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/6d915ca2-1100-4346-a2aa-5ce1e237ef72.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/a6b9ddc7-7873-4975-bb4b-9f0fe33a477b.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/5c4b008d-63d7-41f1-889a-13c7939822ed.jpg',
# ...

# %% [markdown]
# ### Call API at 6.40pm, of 19 Dec 2018

# %%
result_pm = requests.get("https://api.data.gov.sg/v1/transport/traffic-images")

# %%
output_pm = result_pm.json()
output_pm
# Out:
# {'items': [{'timestamp': '2018-12-19T12:49:12+08:00',
#    'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#      'location': {'latitude': 1.29531332, 'longitude': 103.871146},
#      'camera_id': '1001',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': '495591fb44aff1a1b56c6dd1f3538669'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#      'location': {'latitude': 1.319541067, 'longitude': 103.8785627},
#      'camera_id': '1002',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
# ...

# %%
output_pm.keys()
output_pm_items = output_pm['items']

# %%
output_pm_item = {}
for i in output_pm_items:
    print(i)
    print(type(i))
    output_pm_item.update(i)
# Out:
# {'timestamp': '2018-12-19T12:49:12+08:00', 'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg', 'location': {'latitude': 1.29531332, 'longitude': 103.871146}, 'camera_id': '1001', 'image_metadata': {'height': 240, 'width': 320, 'md5': '495591fb44aff1a1b56c6dd1f3538669'}}, {'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg', 'location': {'latitude': 1.319541067, 'longitude': 103.8785627}, 'camera_id': '1002', 'image_metadata': {'height': 240, 'width': 320, 'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}}, {'timestamp': '2018-12-19T12:47:12+08:00', 'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg', 'location': {'latitude': 1.323957439, 'longitude': 103.8728576}, 'camera_id': '1003', 'image_metadata': {'height': 240, 'width': 320, 'md
# ...

# %%
img_pm_urls = []
camera_id_pm = []
# output_item["cameras"] keys are 1)timestamp, 2)image, 3)location, 4)camera_id, 5)image_metadata

for i in output_pm_item["cameras"]:
    img_pm_urls.append((i["image"]))
    camera_id_pm.append((i["camera_id"]))

len(img_pm_urls)
# Out:
# 58

# %%
camera_id_pm
# Out:
# ['1001',
#  '1002',
#  '1003',
#  '1004',
#  '1005',
#  '1006',
#  '1705',
#  '1707',
#  '1709',
#  '9704',
#  '1501',
#  '1502',
#  '1503',
#  '1504',
#  '1505',
#  '2705',
#  '4706',
#  '4708',
#  '1701',
#  '1702',
#  '1704',
#  '1706',
#  '4710',
#  '3796',
#  '6705',
#  '6710',
#  '6711',
#  '6712',
#  '6713',
#  '7795',
#  '1703',
#  '2703',
#  '2704',
#  '3702',
#  '3795',
#  '3797',
#  '4702',
#  '4704',
#  '4705',
#  '4707',
#  '4709',
#  '4712',
#  '4714',
#  '4716',
#  '4798',
#  '4799',
#  '5794',
#  '5795',
#  '5797',
#  '5798',
#  '5799',
#  '6706',
#  '9706',
#  '6701',
#  '7796',
#  '8701',
#  '8702',
#  '8704']

# %%
img_pm_urls
# Out:
# ['https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/d9e1426f-0d66-4423-9f8b-033d0eb537ec.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/588830cc-51f8-4fae-ab0f-9891d8ddf322.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/7783bf53-aac7-4e70-b99a-7336f7612b33.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/d88ed310-4dce-4027-802c-3db7d5c18312.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/83e8a2c5-2b8a-4bde-8a3f-bce0f81f44cf.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/2d6c9e9e-c692-4702-a4b1-50e08fc3b99f.jpg',
# ...

# %%
img_pm_urls = ['https://images.data.gov.sg/api/traffic-images/2018/12/d13d2923-5a61-4421-aa77-f9ba076d83dc.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/b25649d4-7add-4767-9238-f2f8cb77c33e.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/4baf1bff-0611-4318-a466-5aa89efa5644.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/745c2ae8-69fc-458e-ba4d-35d219efe1d0.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/aae07a49-8d8c-4f01-a7b5-82f9fa91b70f.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/a5b375b1-2b1f-42f5-804e-8cae02d7290c.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/c0f68186-8c41-48c5-a78e-2a2a52533b1e.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/c71f181c-9eb9-442c-a867-dc8c91213fad.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/a11c4292-211d-4bcc-9aae-911bb93ef48a.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/5edd6741-b776-49cf-9d4e-e7faa304a759.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/9627e070-d1db-487d-a7e6-2550ce14e039.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/6324c0ae-4c1a-4985-8ffb-f994719fc216.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/3b723cab-12b9-4eee-b4ac-5a369c8ffa20.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/80d672f9-8e4a-423e-8a0d-d425172591b2.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/35c1fbde-40bf-42d4-b2f0-5310d63a330d.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/1fe59b30-c916-4480-872e-623e37c1417b.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/0abc219f-6783-4fe6-ad84-8aa61330a93a.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/bd7635a4-7505-447b-962b-6a886da0d4c9.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/ac2428cb-15eb-4083-9672-aeaf6cdea31a.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/f7616844-f7d0-4e2d-8590-74db402667b8.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/f155c628-fa79-489c-8fe3-5f2e032895bd.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/71e34199-b72f-48a1-8ecd-eb53fef338f7.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/bef8b114-5700-42d6-b6bb-e79ea41f5211.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/463f82ca-907d-4802-9ee5-be1c017ddf2b.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/40dcb955-7742-4d44-a837-c6ab6ef2de86.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/294b8c38-dabb-4f0a-9c97-2abcab4eba6a.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/8c40626b-2897-4efd-8b81-6d0aec4b8326.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/aa7637d8-a34c-43fc-a1ba-f1599e63a008.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/6cb46f3a-aed5-4751-a2db-f7a674618b6f.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/443b3342-9be3-45f2-8325-b3e345415557.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/a805f774-0ef9-4374-8c7f-c37d7600ddab.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/2e33e113-9ef0-4171-a3f2-306d04791531.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/435b9a68-cfd3-42e8-b8c9-feebcd192c36.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/992244c1-7180-4e8d-a12f-2fea18a4449f.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/39c75cae-1015-465b-857d-192a10cdbca8.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/fa850bc1-2585-436d-a15f-e16d545f24c1.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/7d2d47ec-f398-431d-8701-55b82eb33879.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/812c5f7b-77e3-4644-8c85-78638c8aabc2.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12/1e16f895-81da-45e6-81e0-8dd062afd262.jpg',
 'https://images.data.gov.sg/api/traffic-images/2018/12
jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/4baf1bff-0611-4318-a466-5aa89efa5644.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/745c2ae8-69fc-458e-ba4d-35d219efe1d0.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/aae07a49-8d8c-4f01-a7b5-82f9fa91b70f.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/a5b375b1-2b1f-42f5-804e-8cae02d7290c.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/c0f68186-8c41-48c5-a78e-2a2a52533b1e.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/c71f181c-9eb9-442c-a867-dc8c91213fad.jpg',
#  'https://images.data.gov.sg/api/traffic-images/2018/12/a11c4292-211d-4bcc-9aae-911bb93ef48a.jpg',
# ...

# %%
camera_id_pm = [int(x) for x in camera_id_pm]

# %%
camera_id_pm
# Out:
# [1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1705,
#  1707,
#  1709,
#  9704,
#  1501,
#  1502,
#  1503,
#  1504,
#  1505,
#  2705,
#  4706,
#  4708,
#  1701,
#  1702,
#  1704,
#  1706,
#  4710,
#  3796,
#  6705,
#  6710,
#  6711,
#  6712,
#  6713,
#  7795,
#  1703,
#  2703,
#  2704,
#  3702,
#  3795,
#  3797,
#  4702,
#  4704,
#  4705,
#  4707,
#  4709,
#  4712,
#  4714,
#  4716,
#  4798,
#  4799,
#  5794,
#  5795,
#  5797,
#  5798,
#  5799,
#  6706,
#  9706,
#  6701,
#  7796,
#  8701,
#  8702,
#  8704]

# %%
camera_id_pm = [1001,
 1002,
 1003,
 1004,
 1005,
 1006,
 1501,
 1502,
 1503,
 1504,
 1505,
 1701,
 1702,
 1703,
 1704,
 1705,
 1706,
 1707,
 1709,
 1711,
 2702,
 2703,
 2704,
 2705,
 2706,
 2707,
 2708,
 3702,
 3704,
 3705,
 3793,
 3795,
 3796,
 3797,
 3798,
 4701,
 4702,
 4703,
 4704,
 4705,
 4706,
 4707,
 4708,
 4709,
 4710,
 4712,
 4713,
 4714,
 4716,
 4798,
 4799,
 5794,
 5795,
 5797,
 5798,
 5799,
 6701,
 6703,
 6704,
 6705,
 6706,
 6708,
 6710,
 6711,
 6712,
 6713,
 6714,
 6715,
 6716,
 7791,
 7793,
 7794,
 7795,
 7796,
 7797,
 7798,
 8701,
 8702,
 8704,
 8706,
 9701,
 9702,
 9703,
 9704,
 9705,
 9706,
 2701]

# %%
camera_id_pm
# Out:
# [1001,
#  1002,
#  1003,
#  1004,
#  1005,
#  1006,
#  1501,
#  1502,
#  1503,
#  1504,
#  1505,
#  1701,
#  1702,
#  1703,
#  1704,
#  1705,
#  1706,
#  1707,
#  1709,
#  1711,
#  2702,
#  2703,
#  2704,
#  2705,
#  2706,
#  2707,
#  2708,
#  3702,
#  3704,
#  3705,
#  3793,
#  3795,
#  3796,
#  3797,
#  3798,
#  4701,
#  4702,
#  4703,
#  4704,
#  4705,
#  4706,
#  4707,
#  4708,
#  4709,
#  4710,
#  4712,
#  4713,
#  4714,
#  4716,
#  4798,
#  4799,
#  5794,
#  5795,
#  5797,
#  5798,
#  5799,
#  6701,
#  6703,
#  6704,
#  6705,
#  6706,
#  6708,
#  6710,
#  6711,
#  6712,
#  6713,
#  6714,
#  6715,
#  6716,
#  7791,
#  7793,
#  7794,
#  7795,
#  7796,
#  7797,
#  7798,
#  8701,
#  8702,
#  8704,
#  8706,
#  9701,
#  9702,
#  9703,
#  9704,
#  9705,
#  9706,
#  2701]

# %% [markdown]
# #### Both lists are the same

# %%
cam_id_comparison = set(camera_id) & set(camera_id_pm)

# %%
len(cam_id_comparison)
# Out:
# 87

# %% [markdown]
# ### Call API at 9.03AM

# %%
result_am = requests.get("https://api.data.gov.sg/v1/transport/traffic-images")

# %%
output_am = result_am.json()
output_am
# Out:
# {'items': [{'timestamp': '2018-12-19T12:49:12+08:00',
#    'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#      'location': {'latitude': 1.29531332, 'longitude': 103.871146},
#      'camera_id': '1001',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': '495591fb44aff1a1b56c6dd1f3538669'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#      'location': {'latitude': 1.319541067, 'longitude': 103.8785627},
#      'camera_id': '1002',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
# ...

# %%
output_am
# Out:
# {'items': [{'timestamp': '2018-12-19T12:49:12+08:00',
#    'cameras': [{'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/a29d4daa-fccc-465d-ac03-3724e24d8c9b.jpg',
#      'location': {'latitude': 1.29531332, 'longitude': 103.871146},
#      'camera_id': '1001',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': '495591fb44aff1a1b56c6dd1f3538669'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/b513cad9-4f6e-4c89-bf2b-3194df69bd11.jpg',
#      'location': {'latitude': 1.319541067, 'longitude': 103.8785627},
#      'camera_id': '1002',
#      'image_metadata': {'height': 240,
#       'width': 320,
#       'md5': 'a1bb49d5d83ddd57c40a7ff7838feb51'}},
#     {'timestamp': '2018-12-19T12:47:12+08:00',
#      'image': 'https://images.data.gov.sg/api/traffic-images/2018/12/5221296a-3a4a-422c-b655-5fa7fc98e934.jpg',
# ...

# %% [markdown]
# ### Download the images into folder

# %%
from time import sleep
import sys
import urllib.request as request

# %%
print(sys.version)
# Out:
# 3.7.0 (default, Jun 28 2018, 08:04:48) [MSC v.1912 64 bit (AMD64)]

# %%
file_path = "./Traffic_Analysis/images/"

# %%
# import urllib.request as request

# file_path = "./images/"
# for index,url in enumerate(img_urls):
#     file_name = 'noon_'+ str(camera_id[index]) + '.jpg'
#     full_path = file_path + file_name
#     print (url)
#     print(full_path)
#     print(file_name)
# # #     request.urlretrieve(url,full_path)
#     driver.get(url)
# #     sleep(4)
# Out:
# https://images.data.gov.sg/api/traffic-images/2018/12/7571e444-5f1d-41a5-ab23-81b1bd067070.jpg
# ./images/noon_1701.jpg
# noon_1701.jpg
# https://images.data.gov.sg/api/traffic-images/2018/12/b1adeb02-01a6-4d08-a4fc-ef43e124e025.jpg
# ./images/noon_1702.jpg
# noon_1702.jpg
# https://images.data.gov.sg/api/traffic-images/2018/12/b8a4dd07-c7c4-4abb-8aec-f2bc396807aa.jpg
# ./images/noon_1704.jpg
# noon_1704.jpg
# https://images.data.gov.sg/api/traffic-images/2018/12/165c1094-c6a9-46b9-94f2-f874c6bf5b3b.jpg
# ./images/noon_1707.jpg
# noon_1707.jpg
# https://images.data.gov.sg/api/traffic-images/2018/12/4bff3059-ef0f-46e7-8f17-7855de1c2213.jpg
# ./images/noon_1709.jpg
# noon_1709.jpg
# https://images.data.gov.sg/api/traffic-images/2018/12/c33f2ff3-5af8-4bf3-972f-c12d6f025f4a.jpg
# ./images/noon_1711.jpg
# noon_1711.jpg
# https://images.data.gov.sg/api/traffic-images/2018/12/6d915ca2-1100-4346-a2aa-5ce1e237ef72.jpg
# ./images/noon_2701.jpg
# noon_2701.jpg
# ...

# %%
import requests
import urllib
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36')]
urllib.request.install_opener(opener)
# urllib.request.urlretrieve("type URL here", "path/file_name")
def dl_jpg(image_list, camera_list):
    for index,url in enumerate(image_list):
        file_name = 'noon_'+ str(camera_list[index]) + '.jpg'
#         full_path = file_path + file_name
#         print(file_name)
        print(str(index)+url)
#         headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
#         requests.get(url, headers = headers)
        urllib.request.urlretrieve(url, file_name)   
        sleep(5)

# %%
file_path = "./Traffic_Analysis/images/"
time_of_day = input('Enter am/noon/pm:')
def dl_image(image_list, camera_list, time_of_day):
    for index,url in enumerate(image_list):
        file_name = time_of_day + '_'+ str(camera_list[index]) + '.jpg'
        full_path = file_path + file_name
#         print(file_name)
        print(str(index)+url)
#         headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
#         requests.get(url, headers = headers)
        urllib.request.urlretrieve(url, full_path)   
        sleep(5)
# Out:
# Enter am/noon/pm:pm

# %%
dl_image(img_pm_urls, camera_id_pm, time_of_day)
# Out:
# 0https://images.data.gov.sg/api/traffic-images/2018/12/d13d2923-5a61-4421-aa77-f9ba076d83dc.jpg
# 1https://images.data.gov.sg/api/traffic-images/2018/12/b25649d4-7add-4767-9238-f2f8cb77c33e.jpg
# 2https://images.data.gov.sg/api/traffic-images/2018/12/4baf1bff-0611-4318-a466-5aa89efa5644.jpg
# 3https://images.data.gov.sg/api/traffic-images/2018/12/745c2ae8-69fc-458e-ba4d-35d219efe1d0.jpg
# 4https://images.data.gov.sg/api/traffic-images/2018/12/aae07a49-8d8c-4f01-a7b5-82f9fa91b70f.jpg
# 5https://images.data.gov.sg/api/traffic-images/2018/12/a5b375b1-2b1f-42f5-804e-8cae02d7290c.jpg
# 6https://images.data.gov.sg/api/traffic-images/2018/12/c0f68186-8c41-48c5-a78e-2a2a52533b1e.jpg
# 7https://images.data.gov.sg/api/traffic-images/2018/12/c71f181c-9eb9-442c-a867-dc8c91213fad.jpg
# 8https://images.data.gov.sg/api/traffic-images/2018/12/a11c4292-211d-4bcc-9aae-911bb93ef48a.jpg
# 9https://images.data.gov.sg/api/traffic-images/2018/12/5edd6741-b776-49cf-9d4e-e7faa304a759.jpg
# ...

# %%
dl_jpg(img_urls, camera_id)
# Out:
# 0https://images.data.gov.sg/api/traffic-images/2018/12/7571e444-5f1d-41a5-ab23-81b1bd067070.jpg
# 1https://images.data.gov.sg/api/traffic-images/2018/12/b1adeb02-01a6-4d08-a4fc-ef43e124e025.jpg
# 2https://images.data.gov.sg/api/traffic-images/2018/12/b8a4dd07-c7c4-4abb-8aec-f2bc396807aa.jpg
# 3https://images.data.gov.sg/api/traffic-images/2018/12/165c1094-c6a9-46b9-94f2-f874c6bf5b3b.jpg
# 4https://images.data.gov.sg/api/traffic-images/2018/12/4bff3059-ef0f-46e7-8f17-7855de1c2213.jpg
# 5https://images.data.gov.sg/api/traffic-images/2018/12/c33f2ff3-5af8-4bf3-972f-c12d6f025f4a.jpg
# 6https://images.data.gov.sg/api/traffic-images/2018/12/6d915ca2-1100-4346-a2aa-5ce1e237ef72.jpg
# 7https://images.data.gov.sg/api/traffic-images/2018/12/a6b9ddc7-7873-4975-bb4b-9f0fe33a477b.jpg
# 8https://images.data.gov.sg/api/traffic-images/2018/12/5c4b008d-63d7-41f1-889a-13c7939822ed.jpg
# 9https://images.data.gov.sg/api/traffic-images/2018/12/56c2cd81-1a6d-4a1d-b50b-3109510918c5.jpg
# ...
